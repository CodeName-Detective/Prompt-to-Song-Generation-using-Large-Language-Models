# %%
import pandas as pd

# %%
df = pd.read_csv('data/prompt_golden_data.csv')

# %%
df.shape
# Out:
# (7712, 5)

# %%
from sklearn.utils import shuffle

# %%
df = shuffle(df)

# %%
df.shape[0]/2
# Out:
# 3856.0

# %%
df1 = df[:3856]

# %%
df2 = df[3856:]

# %%
df1['reward'] = 1
# Out:
# /var/folders/s_/k3msb6312d71bp7h_wr838_c0000gn/T/ipykernel_76993/350774825.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['reward'] = 1

# %%
df1
# Out:
#                                                  genres         progression  \
# 3733  ['contemporary country', 'country', 'country d...     ['D', 'A', 'D']
# 689   ['hip hop', 'indie pop rap', 'oakland hip hop'...     ['C', 'G', 'A']
# 1555  ['album rock', 'classic rock', 'country rock',...     ['F', 'C', 'F']
# 5033  ['israeli mediterranean', 'israeli pop', 'mizr...    ['G', 'F', 'Em']
# 5746  ['ccm', 'christian alternative rock', 'christi...  ['D/F#', 'G', 'D']
# ...                                                 ...                 ...
# 600   ['boy band', 'dance pop', 'electropop', 'pop',...    ['F', 'Am', 'F']
# 1610  ['adult standards', 'contemporary vocal jazz',...     ['C', 'F', 'C']
# 4508  ['alternative rock', 'art pop', 'art rock', 'i...    ['D', 'Em', 'G']
# 6221  ['adult standards', 'brill building pop', 'bub...   ['F7', 'C', 'G7']
# 108                   ['dfw rap', 'melodic rap', 'rap']     ['B', 'E', 'A']
#
#      start_key                                   processed_lyrics  \
# 3733         A  \n\nVerse 1 \nI overheard a conversation your ...
# 689          E  \n\t  \t\t\n\nYou know if I say something I me...
# 1555         C  \n\t  \t\t\n\nIntro is repeated at the end of ...
# 5033        Am  \n\t  \t\tChord Arrangement by Chaim Kastel \n...
# 5746        Em  \n\nWhat Child is this who\nlaid to rest  \nOn...
# ...        ...                                                ...
# 600          C  \n\t  \t\t\n\n\nTonight we're fading fast \nI ...
# 1610         F  \n\t  \t\tTransposed from the original by Will...
# 4508        Bm  \n\t  \t\t\n\nverse \n\nWhat was sent to the s...
# 6221         C  \n\t  \t\t \n\nI'm sorry\nso sorry \nThat I wa...
# 108        C#m  \nRiff \n\n\n\nI feel you crumble in my arms d...
#
#                                                 prompts  reward
# 3733                          Rumor has it she has you.       1
# 689   If I ever said I'm never scared, I mean it whe...       1
# 1555                          Fare thee well, my honey.       1
# 5033  Al osher bli dai  ishebitoo einay  islech malc...       1
# 5746  Shepherds guard and Angels sing to bring Him t...       1
# ...                                                 ...     ...
# 600                     Tonight we will make this last.       1
# 1610   Willie Nelson's version of Willie Nelson's song.       1
# 4508  From the ancient city of prague came a pair of...       1
# 6221  I'm sorry, I was such a fool. I didn't know lo...       1
# 108   I feel you crumble in my arms down to your hea...       1
#
# [3856 rows x 6 columns]

# %%
df2
# Out:
#                                                  genres  \
# 331        ['dance pop', 'pop', 'post-teen pop', 'r&b']
# 6736                                   ['metropopolis']
# 4006           ['indie garage rock', 'neo-psychedelic']
# 6815  ['anthem worship', 'ccm', 'christian alternati...
# 1833  ['album rock', 'art rock', 'beatlesque', 'clas...
# ...                                                 ...
# 2800                       ['australian reggae fusion']
# 480                              ['pop', 'r&b', 'soul']
# 5847                                   ['anarcho-punk']
# 1829  ['album rock', 'art rock', 'beatlesque', 'clas...
# 2217                ['mpb', 'nova mpb', 'pop nacional']
#
#                         progression start_key  \
# 331           ['C7', 'F7M', 'F9/G']         C
# 6736                ['F', 'C', 'C']        Am
# 4006            ['Bb', 'Ebm', 'G#']        Fm
# 6815               ['D', 'Bb', 'D']        Eb
# 1833               ['E', 'Am', 'E']        Am
# ...                             ...       ...
# 2800     ['Emaj9', 'C#m9', 'Emaj9']      C#m9
# 480   ['Fmaj7', 'Dbmaj7', 'Abmaj7']     Fmaj7
# 5847              ['Em', 'E', 'Em']         E
# 1829                ['G', 'x', '2']         C
# 2217              ['B', 'Gb', 'Db']       Bbm
#
#                                        processed_lyrics  \
# 331   \n\t  \t\t\n\nBring the beat in! \n\nHoney\nho...
# 6736  \n\t  \t\t\n\n\n\nVERSE 1 \n\nRunning through ...
# 4006  \n\t  \t\t\n\n\nLeave Behind just too delicate...
# 6815  \nVerse: 1 \nSo long\nMoses \nHello\nPromised ...
# 1833  \n\nI'm very sure\nthis never happened to me b...
# ...                                                 ...
# 2800  \n\t  \t\t\n\nVerse \nI crouch in the snow \nD...
# 480   \n\t  \t\t\n\n\nverse 1 \nHold my hand\nfeel t...
# 5847  \n\t  \t\t\n(Spoken) \nI'm the Boss of the com...
# 1829  \nPeaceful\nLike Heaven On A Sunday.  \nWishfu...
# 2217  \nTu vens\ntu vens \n  Eu já escuto os teus si...
#
#                                                 prompts
# 331   Ponte is smiling up from ear to ear. He can se...
# 6736                 It finally feels like coming home.
# 4006    Leave Behind just too delicate to leave Behind.
# 6815  The kingdom of Israel is broken now and the pe...
# 1833  I met you and now I'm sure this never happened...
# ...                                                 ...
# 2800  I crouch in the snow. I don?t want to let the ...
# 480            It's a brand new day and the sun is out.
# 5847  A million pounds will be given away to pop sta...
# 1829  If I Only Had One Love   Yours Would Be The On...
# 2217  Three little birds sat on my window and told m...
#
# [3856 rows x 5 columns]

# %%
df2['progression'] = shuffle(df2['progression']).tolist()
# Out:
# /var/folders/s_/k3msb6312d71bp7h_wr838_c0000gn/T/ipykernel_76993/2809829149.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['progression'] = shuffle(df2['progression']).tolist()

# %%
df2
# Out:
#                                                  genres           progression  \
# 331        ['dance pop', 'pop', 'post-teen pop', 'r&b']      ['D', 'Bb', 'D']
# 6736                                   ['metropopolis']  ['G/B', 'Em7', 'Am']
# 4006           ['indie garage rock', 'neo-psychedelic']   ['C#m', 'F#m', 'B']
# 6815  ['anthem worship', 'ccm', 'christian alternati...     ['A', 'E', 'F#m']
# 1833  ['album rock', 'art rock', 'beatlesque', 'clas...  ['D', 'G', 'Am13/E']
# ...                                                 ...                   ...
# 2800                       ['australian reggae fusion']      ['F', 'G', 'Am']
# 480                              ['pop', 'r&b', 'soul']     ['Em7', 'D', 'C']
# 5847                                   ['anarcho-punk']      ['Am', 'F', 'C']
# 1829  ['album rock', 'art rock', 'beatlesque', 'clas...     ['Em', 'F', 'Fm']
# 2217                ['mpb', 'nova mpb', 'pop nacional']     ['A9', 'Bm', 'G']
#
#      start_key                                   processed_lyrics  \
# 331          C  \n\t  \t\t\n\nBring the beat in! \n\nHoney\nho...
# 6736        Am  \n\t  \t\t\n\n\n\nVERSE 1 \n\nRunning through ...
# 4006        Fm  \n\t  \t\t\n\n\nLeave Behind just too delicate...
# 6815        Eb  \nVerse: 1 \nSo long\nMoses \nHello\nPromised ...
# 1833        Am  \n\nI'm very sure\nthis never happened to me b...
# ...        ...                                                ...
# 2800      C#m9  \n\t  \t\t\n\nVerse \nI crouch in the snow \nD...
# 480      Fmaj7  \n\t  \t\t\n\n\nverse 1 \nHold my hand\nfeel t...
# 5847         E  \n\t  \t\t\n(Spoken) \nI'm the Boss of the com...
# 1829         C  \nPeaceful\nLike Heaven On A Sunday.  \nWishfu...
# 2217       Bbm  \nTu vens\ntu vens \n  Eu já escuto os teus si...
#
#                                                 prompts
# 331   Ponte is smiling up from ear to ear. He can se...
# 6736                 It finally feels like coming home.
# 4006    Leave Behind just too delicate to leave Behind.
# 6815  The kingdom of Israel is broken now and the pe...
# 1833  I met you and now I'm sure this never happened...
# ...                                                 ...
# 2800  I crouch in the snow. I don?t want to let the ...
# 480            It's a brand new day and the sun is out.
# 5847  A million pounds will be given away to pop sta...
# 1829  If I Only Had One Love   Yours Would Be The On...
# 2217  Three little birds sat on my window and told m...
#
# [3856 rows x 5 columns]

# %%
df2['reward'] = -1
# Out:
# /var/folders/s_/k3msb6312d71bp7h_wr838_c0000gn/T/ipykernel_76993/3779626051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['reward'] = -1

# %%
df = pd.concat([df1,df2], ignore_index=True)

# %%
df.to_csv('data/prompt_golden_data.csv', index=False)

# %%
df = shuffle(df)

# %%
df
# Out:
#                                                  genres         progression  \
# 0     ['contemporary country', 'country', 'country d...     ['D', 'A', 'D']
# 1     ['hip hop', 'indie pop rap', 'oakland hip hop'...     ['C', 'G', 'A']
# 2     ['album rock', 'classic rock', 'country rock',...     ['F', 'C', 'F']
# 3     ['israeli mediterranean', 'israeli pop', 'mizr...    ['G', 'F', 'Em']
# 4     ['ccm', 'christian alternative rock', 'christi...  ['D/F#', 'G', 'D']
# ...                                                 ...                 ...
# 7707                       ['australian reggae fusion']    ['F', 'G', 'Am']
# 7708                             ['pop', 'r&b', 'soul']   ['Em7', 'D', 'C']
# 7709                                   ['anarcho-punk']    ['Am', 'F', 'C']
# 7710  ['album rock', 'art rock', 'beatlesque', 'clas...   ['Em', 'F', 'Fm']
# 7711                ['mpb', 'nova mpb', 'pop nacional']   ['A9', 'Bm', 'G']
#
#      start_key                                   processed_lyrics  \
# 0            A  \n\nVerse 1 \nI overheard a conversation your ...
# 1            E  \n\t  \t\t\n\nYou know if I say something I me...
# 2            C  \n\t  \t\t\n\nIntro is repeated at the end of ...
# 3           Am  \n\t  \t\tChord Arrangement by Chaim Kastel \n...
# 4           Em  \n\nWhat Child is this who\nlaid to rest  \nOn...
# ...        ...                                                ...
# 7707      C#m9  \n\t  \t\t\n\nVerse \nI crouch in the snow \nD...
# 7708     Fmaj7  \n\t  \t\t\n\n\nverse 1 \nHold my hand\nfeel t...
# 7709         E  \n\t  \t\t\n(Spoken) \nI'm the Boss of the com...
# 7710         C  \nPeaceful\nLike Heaven On A Sunday.  \nWishfu...
# 7711       Bbm  \nTu vens\ntu vens \n  Eu já escuto os teus si...
#
#                                                 prompts  reward
# 0                             Rumor has it she has you.       1
# 1     If I ever said I'm never scared, I mean it whe...       1
# 2                             Fare thee well, my honey.       1
# 3     Al osher bli dai  ishebitoo einay  islech malc...       1
# 4     Shepherds guard and Angels sing to bring Him t...       1
# ...                                                 ...     ...
# 7707  I crouch in the snow. I don?t want to let the ...      -1
# 7708           It's a brand new day and the sun is out.      -1
# 7709  A million pounds will be given away to pop sta...      -1
# 7710  If I Only Had One Love   Yours Would Be The On...      -1
# 7711  Three little birds sat on my window and told m...      -1
#
# [7712 rows x 6 columns]

# %%
from src.data import get_data

# %%
train, _ = get_data(2)
# Out:
# Map:   0%|          | 0/6940 [00:00<?, ? examples/s]
# Map:   0%|          | 0/772 [00:00<?, ? examples/s]

# %%
for batch in train:
    key = 'chord_vector'
    output = batch[key]
    print(batch[key].shape)
    break
# Out:
# torch.Size([2, 543])

# %%
sum(output[0] == 1.)
# Out:
# tensor(1)
